# %% [markdown]
# # Flavours of Physics: Finding τ → μμμ: Identify a rare decay phenomenon
# Link: <https://www.kaggle.com/competitions/flavours-of-physics>
#
# **About the dataset:**

# %% [markdown]
# ## Imports

# %%
from pathlib import Path

# %% [markdown]
# ## Getting the data

# %%
# Uncomment this when pushing notebook to kaggle.

train_zip = '/kaggle/input/flavours-of-physics/training.csv.zip'
test_zip = '/kaggle/input/flavours-of-physics/test.csv.zip'

# While working in the local machine.

# %%
# !kaggle kernels init
# Out:
# Kernel metadata template written to: c:\Users\rames\Desktop\GitHub\deep_learning\project-flavours_of_physics_finding_τ→μμμ\kernel-metadata.json
